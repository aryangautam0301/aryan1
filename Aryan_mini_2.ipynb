# %% [markdown]
# <a href="https://colab.research.google.com/github/aryangautam0301/aryan1/blob/main/Aryan_mini_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install numpy\<2

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
climate_data = pd.read_csv('/content/DATA ONE (1).csv')

# %%
climate_data.head()
# Out:
#       Date          Location        Country  Temperature  CO2 Emissions  \
# 0  00:00.0   New Williamtown         Latvia    10.688986     403.118902
# 1  09:43.3      North Rachel   South Africa    13.814430     396.663499
# 2  19:26.5  West Williamland  French Guiana    27.323718     451.553155
# 3  29:09.8       South David        Vietnam    12.309581     422.404984
# 4  38:53.0    New Scottburgh        Moldova    13.210885     410.472999
#
#    Sea Level Rise  Precipitation   Humidity  Wind Speed
# 0        0.717506      13.835237  23.631256   18.492026
# 1        1.205715      40.974084  43.982946   34.249300
# 2       -0.160783      42.697931  96.652600   34.124261
# 3       -0.475931       5.193341  47.467938    8.554563
# 4        1.135757      78.695280  61.789672    8.001164

# %%
climate_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            10000 non-null  object
#  1   Location        10000 non-null  object
#  2   Country         10000 non-null  object
#  3   Temperature     10000 non-null  float64
#  4   CO2 Emissions   10000 non-null  float64
#  5   Sea Level Rise  10000 non-null  float64
#  6   Precipitation   10000 non-null  float64
#  7   Humidity        10000 non-null  float64
#  8   Wind Speed      10000 non-null  float64
# dtypes: float64(6), object(3)
# memory usage: 703.3+ KB

# %%
climate_data.isnull().sum()
# Out:
# Date              0
# Location          0
# Country           0
# Temperature       0
# CO2 Emissions     0
# Sea Level Rise    0
# Precipitation     0
# Humidity          0
# Wind Speed        0
# dtype: int64

# %%
climate_data=climate_data.dropna()

# %%
climate_data.isnull().sum()
# Out:
# Date              0
# Location          0
# Country           0
# Temperature       0
# CO2 Emissions     0
# Sea Level Rise    0
# Precipitation     0
# Humidity          0
# Wind Speed        0
# dtype: int64

# %%
climate_data['dt'] = pd.to_datetime(climate_data['Date'], errors='coerce') # Assuming 'Date' is the column containing date information
climate_data.set_index('dt',inplace=True)
# Out:
# <ipython-input-13-cba9f0ec5a73>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   climate_data['dt'] = pd.to_datetime(climate_data['Date'], errors='coerce') # Assuming 'Date' is the column containing date information

# %%
climate_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10000 entries, 2025-03-09 00:00:00 to 2025-03-09 00:00:00
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            10000 non-null  object
#  1   Location        10000 non-null  object
#  2   Country         10000 non-null  object
#  3   Temperature     10000 non-null  float64
#  4   CO2 Emissions   10000 non-null  float64
#  5   Sea Level Rise  10000 non-null  float64
#  6   Precipitation   10000 non-null  float64
#  7   Humidity        10000 non-null  float64
#  8   Wind Speed      10000 non-null  float64
# dtypes: float64(6), object(3)
# memory usage: 781.2+ KB

# %%
climate_data.shape
# Out:
# (10000, 9)

# %%
climate_data.describe()
# Out:
#         Temperature  CO2 Emissions  Sea Level Rise  Precipitation  \
# count  10000.000000   10000.000000    10000.000000   10000.000000
# mean      14.936034     400.220469       -0.003152      49.881208
# std        5.030616      49.696933        0.991349      28.862417
# min       -3.803589     182.131220       -4.092155       0.010143
# 25%       11.577991     367.109330       -0.673809      24.497516
# 50%       14.981136     400.821324        0.002332      49.818967
# 75%       18.305826     433.307905        0.675723      74.524991
# max       33.976956     582.899701        4.116559      99.991900
#
#            Humidity    Wind Speed
# count  10000.000000  10000.000000
# mean      49.771302     25.082066
# std       28.929320     14.466648
# min        0.018998      0.001732
# 25%       24.713250     12.539733
# 50%       49.678412     24.910787
# 75%       75.206390     37.670260
# max       99.959665     49.997664

# %%
climate_data['Year'] = climate_data.index.year

# %%
climate_data.head()
# Out:
#                         Date          Location        Country  Temperature  \
# dt
# 2025-03-09 00:00:00  00:00.0   New Williamtown         Latvia    10.688986
# 2025-03-09 09:43:18  09:43.3      North Rachel   South Africa    13.814430
# 2025-03-09 19:26:30  19:26.5  West Williamland  French Guiana    27.323718
# NaT                  29:09.8       South David        Vietnam    12.309581
# NaT                  38:53.0    New Scottburgh        Moldova    13.210885
#
#                      CO2 Emissions  Sea Level Rise  Precipitation   Humidity  \
# dt
# 2025-03-09 00:00:00     403.118902        0.717506      13.835237  23.631256
# 2025-03-09 09:43:18     396.663499        1.205715      40.974084  43.982946
# 2025-03-09 19:26:30     451.553155       -0.160783      42.697931  96.652600
# NaT                     422.404984       -0.475931       5.193341  47.467938
# NaT                     410.472999        1.135757      78.695280  61.789672
#
#                      Wind Speed    Year
# ...

# %%
climate_data.isnull().sum()
# Out:
# Date                 0
# Location             0
# Country              0
# Temperature          0
# CO2 Emissions        0
# Sea Level Rise       0
# Precipitation        0
# Humidity             0
# Wind Speed           0
# Year              5994
# dtype: int64

# %%
climate_data.describe()
# Out:
#         Temperature  CO2 Emissions  Sea Level Rise  Precipitation  \
# count  10000.000000   10000.000000    10000.000000   10000.000000
# mean      14.936034     400.220469       -0.003152      49.881208
# std        5.030616      49.696933        0.991349      28.862417
# min       -3.803589     182.131220       -4.092155       0.010143
# 25%       11.577991     367.109330       -0.673809      24.497516
# 50%       14.981136     400.821324        0.002332      49.818967
# 75%       18.305826     433.307905        0.675723      74.524991
# max       33.976956     582.899701        4.116559      99.991900
#
#            Humidity    Wind Speed    Year
# count  10000.000000  10000.000000  4006.0
# mean      49.771302     25.082066  2025.0
# std       28.929320     14.466648     0.0
# min        0.018998      0.001732  2025.0
# 25%       24.713250     12.539733  2025.0
# 50%       49.678412     24.910787  2025.0
# 75%       75.206390     37.670260  2025.0
# ...

# %%
climate_data.sort_index(inplace=True)

# %%
climate_data.sort_index(inplace=True)  # Ensure DateTimeIndex is sorted

# Get the actual start and end dates in your data
start_date = climate_data.index.min()
end_date = climate_data.index.max()

# Print the start and end dates to check
print(f"Start date in data: {start_date}")
print(f"End date in data: {end_date}")

# Slice using the actual dates or a range within your data
# For example, to get data from the minimum date to the maximum date:
latest_df = climate_data.loc[start_date:end_date]

# Or, if you want a specific range within your data, adjust the dates accordingly:
# latest_df = climate_data.loc['1980-01-01':end_date]
# assuming '1980-01-01' is within your data range

# Now the slicing operation should work
# Out:
# Start date in data: 2025-03-09 00:00:00
# End date in data: 2025-03-09 23:58:42

# %%
latest_df[['Country','Temperature']].groupby(['Country']).mean().sort_values ('Temperature')
# Out:
#                           Temperature
# Country
# Eritrea                     10.966466
# Belarus                     11.084696
# Kazakhstan                  11.696918
# Poland                      11.762071
# Solomon Islands             11.972732
# ...                               ...
# Slovenia                    17.795112
# Tuvalu                      17.863877
# Liechtenstein               17.911228
# Uruguay                     17.947991
# Turks and Caicos Islands    18.725348
#
# [243 rows x 1 columns]

# %%
plt.figure(figsize=(7, 7))
# Check for the correct column name and use it below
# If 'Temperature' is not the correct column name, replace it with the actual column name

# %%
resample_df = latest_df[['Temperature']].resample('A').mean() # Changed 'AverageTemperature' to 'Temperature'
# Out:
# <ipython-input-25-bea351850986>:1: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   resample_df = latest_df[['Temperature']].resample('A').mean() # Changed 'AverageTemperature' to 'Temperature'

# %%
resample_df.head()
# Out:
#             Temperature
# dt
# 2025-12-31    15.049028

# %%
resample_df.plot(title='Temperature Changes from 1980-2013',figsize=(8,5))
plt.ylabel('Temperature',fontsize=12)
plt.xlabel('Year',fontsize=12)
plt.legend()
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas/plotting/_matplotlib/core.py:1561: UserWarning: Attempting to set identical low and high xlims makes transformation singular; automatically expanding.
#   ax.set_xlim(left, right)

# %%
# Ensure 'climate_data' has enough data for resampling
resample_df = climate_data[['Temperature']].resample('A').mean()
# Out:
# <ipython-input-28-59f4b43a1ad3>:2: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   resample_df = climate_data[['Temperature']].resample('A').mean()

# %%
import pandas as pd
from statsmodels.tsa.seasonal import seasonal_decompose

# Assuming 'climate_data' is your original DataFrame

# Resample

# %%
import pandas as pd
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt

# Assuming 'climate_data' is your original DataFrame with a DateTimeIndex named 'dt'

# 1. Resample to a lower frequency if you have limited data
# For example, if you have daily data, resample to monthly:
climate_data['Temperature'] = pd.to_numeric(climate_data['Temperature'], errors='coerce')
climate_data = climate_data.dropna(subset=['Temperature'])
resample_df = climate_data[['Temperature']].resample('M').mean()  # 'M' for monthly, 'W' for weekly

# 2. Ensure you have enough data after resampling
print(f"Number of observations after resampling: {len(resample_df)}")

# 3. If you have enough
# Out:
# Number of observations after resampling: 1
# <ipython-input-30-affaf1a8577f>:11: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   resample_df = climate_data[['Temperature']].resample('M').mean()  # 'M' for monthly, 'W' for weekly

# %%
rol_mean = resample_df.rolling(window=3, center=True).mean()
ewm = resample_df.ewm(span=3).mean()
rol_std = resample_df.rolling(window=3, center=True).std()
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12,5))

ax1.plot(resample_df,label= 'Original')
ax1.plot(rol_mean, label='Rolling Mean')
ax1.plot (ewm, label='Exponentially Weighted Mean')
ax1.set_title('Temperature Changes from 1980-2013',fontsize=14)
ax1. set_ylabel ( 'Temperature', fontsize=12)
ax1.set_xlabel ('Year', fontsize=12)
ax1.legend()

ax2.plot(rol_std,label= 'Rolling STD')
ax2.set_title('Temperature Changes from 1980-2013',fontsize=14)
ax2. set_ylabel ( 'Temperature', fontsize=12)
ax2.set_xlabel ('Year', fontsize=12)
ax2.legend()

plt.tight_layout()

# %%
# !pip install statsmodels
import pandas as pd
from statsmodels.tsa.stattools import adfuller
import matplotlib.pyplot as plt

# Assuming 'climate_data' is your original DataFrame with a DateTimeIndex named 'dt'

# 1. Resample to a lower frequency if you have limited data

# %%
diff_rol_mean = resample_df - rol_mean
diff_rol_mean.dropna(inplace = True)
diff_rol_mean.head()
# Out:
# Empty DataFrame
# Columns: [Temperature]
# Index: []

# %%
diff_ewm = resample_df - ewm
diff_ewm.dropna(inplace = True)
diff_ewm.head()
# Out:
#             Temperature
# dt
# 2025-03-31          0.0

# %%
df_rol_mean_diff = diff_rol_mean.rolling(window=3, center=True).mean()

df_ewm_diff = diff_ewm.ewm(span=3).mean()
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,4))

ax1.plot(diff_rol_mean,label= 'Original')
ax1.plot(df_rol_mean_diff, label='Rolling Mean')
ax1.plot (ewm, label='Exponentially Weighted Mean')
ax1.set_title('Temperature Changes from 1980-2013',fontsize=14)
ax1.set_ylabel( 'Temperature', fontsize=12)
ax1.set_xlabel('Year', fontsize=12)
ax1.legend()

ax2.plot(diff_ewm,label= 'Original ')
ax2.plot(df_ewm_diff,label= 'Exponentially Weighted Mean')
ax2.set_title('Temperature Changes from 1980-2013',fontsize=14)
ax2. set_ylabel ( 'Temperature', fontsize=12)
ax2.set_xlabel ('Year', fontsize=12)
ax2.legend()

plt.tight_layout()

# %%
# !pip install statsmodels
import pandas as pd
from statsmodels.tsa.stattools import adfuller
import matplotlib.pyplot as plt

# Assuming 'climate_data' is your original DataFrame with a DateTimeIndex named 'dt'

# 1. Resample to a lower frequency if you have limited data

# ... (Your previous code for calculating 'resample_df' and 'rol_mean')

# Check if diff_rol_mean is empty before applying adfuller
if diff_rol_mean.empty:
    print("diff_rol_mean is empty. Cannot perform Dickey-Fuller test.")
else:
    print('Dickey Fuller Test for Rolling mean:')
    test_df = adfuller(diff_rol_mean.iloc[:, 0].values, autolag='AIC')
    df_output = pd.Series(test_df[0:4], index=['Test Statistic', 'p-value', 'Lags Used', 'Number of Observations Used '])
    for key, value in test_df[4].items():
        df_output['Critical Value (%s) '%key] = value
    print(df_output)
    print('')

# Similar check for diff_ewm, also check for constant values
# Out:
# ...
# diff_rol_mean is empty. Cannot perform Dickey-Fuller test.

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from matplotlib import pyplot

# Increase the lags to cover a wider range, but within the available data
lags = min(10, len(resample_df))

# %%
monthly_avg_temp = climate_data.groupby(pd.Grouper(freq='M'))['Temperature'].mean().reset_index()
# Out:
# <ipython-input-38-3ff1fd5c3d8c>:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_avg_temp = climate_data.groupby(pd.Grouper(freq='M'))['Temperature'].mean().reset_index()
